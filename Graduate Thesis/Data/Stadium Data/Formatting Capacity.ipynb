# %% [markdown]
# This notebook reformats stadium capacity data.

# %%
import pandas as pd

df = pd.read_csv("StadiumCapacities.csv")

# %%
df = df.set_index('Team')
df
# Out:
#                      2000      2001      2002      2003      2004      2005  \
# Team
# Air Force         52480.0   52480.0   52480.0   52480.0   52480.0   46692.0
# Akron             31000.0   31000.0   31000.0   31000.0   31000.0   31000.0
# Alabama           83818.0   83818.0   83818.0   83818.0   83818.0   92138.0
# Appalachian St.       NaN       NaN       NaN       NaN       NaN       NaN
# Arizona           56002.0   56002.0   56002.0   56002.0   56002.0   56002.0
# Arizona St.       73656.0   73656.0   73656.0   73656.0   73656.0   73656.0
# Arkansas          72000.0   72000.0   72000.0   72000.0   72000.0   72000.0
# Arkansas St.      30406.0   30406.0   30406.0   30406.0   30406.0   30406.0
# Army              38115.0   38115.0   38115.0   38115.0   38115.0   38115.0
# Auburn            87451.0   87451.0   87451.0   87451.0   87451.0   87451.0
# Ball St.          22500.0   22500.0   22500.0   22500.0   22500.0   22500.0
# ...

# %%
finalData = df.stack()

finalData
# Out:
# Team
# Air Force  2000     52480
#            2001     52480
#            2002     52480
#            2003     52480
#            2004     52480
#            2005     46692
#            2006     46692
#            2007     52480
#            2008     46692
#            2009     46692
#            2010     46692
#            2011     46692
#            2012     46692
#            2013    46,692
#            2014    46,692
#            2015    46,692
#            2016    46,692
# Akron      2000     31000
#            2001     31000
#            2002     31000
#            2003     31000
#            2004     31000
#            2005     31000
#            2006     31000
#            2007     35202
#            2008     35202
#            2009     30000
#            2010     30000
#            2011     27881
#            2012     30000
#                     ...
# Wisconsin  2004     80360
#            2005     80360
#            2006     80360
#            2007     80321
# ...

# %%
finalData.to_csv("FinalStadiumCapacities.csv")
