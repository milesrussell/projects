# %%
import pandas as pd

df = pd.read_csv("~/projects/Graduate Thesis/Data/State Data/State Population/statepops.csv")

df
# Out:
#               state        2010        2011        2012        2013  \
# 0          .Alabama   4,785,579   4,798,649   4,813,946   4,827,660
# 1          .Arizona   6,407,002   6,465,488   6,544,211   6,616,124
# 2         .Arkansas   2,921,737   2,938,640   2,949,208   2,956,780
# 3       .California  37,327,690  37,672,654  38,019,006  38,347,383
# 4         .Colorado   5,048,029   5,116,411   5,186,330   5,262,556
# 5      .Connecticut   3,580,171   3,591,927   3,597,705   3,602,470
# 6          .Florida  18,846,461  19,097,369  19,341,327  19,584,927
# 7          .Georgia   9,712,696   9,810,595   9,911,171   9,981,773
# 8           .Hawaii   1,363,817   1,378,323   1,392,772   1,408,038
# 9            .Idaho   1,570,912   1,583,180   1,594,673   1,610,187
# 10        .Illinois  12,841,196  12,862,298  12,878,494  12,890,403
# 11         .Indiana   6,490,029   6,515,358   6,535,665   6,567,484
# 12            .Iowa   3,050,223   3,063,690   3,074,386   3,089,876
# ...

# %%
df = df.set_index('state')

# %%
df = df.stack()

df
# Out:
# state
# .Alabama        2010     4,785,579
#                 2011     4,798,649
#                 2012     4,813,946
#                 2013     4,827,660
#                 2014     4,840,037
# .Arizona        2010     6,407,002
#                 2011     6,465,488
#                 2012     6,544,211
#                 2013     6,616,124
#                 2014     6,706,435
# .Arkansas       2010     2,921,737
#                 2011     2,938,640
#                 2012     2,949,208
#                 2013     2,956,780
#                 2014     2,964,800
# .California     2010    37,327,690
#                 2011    37,672,654
#                 2012    38,019,006
#                 2013    38,347,383
#                 2014    38,701,278
# .Colorado       2010     5,048,029
#                 2011     5,116,411
#                 2012     5,186,330
#                 2013     5,262,556
#                 2014     5,342,311
# .Connecticut    2010     3,580,171
# ...

# %%
df.to_csv("~/projects/Graduate Thesis/Data/State Data/State Population/final_state_populations.csv")
