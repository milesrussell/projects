# %% [markdown]
# ### Loading in libraries, preparing for analysis

# %%
# importing needed libraries for two stage least squares and ols
import pandas as pd
from linearmodels.iv import IV2SLS
from linearmodels.panel import PanelOLS
from linearmodels.panel import PooledOLS
import statsmodels.api as sm


# reading in the data
df = pd.read_csv("~/projects/Graduate Thesis/Data/FinalCSV.csv", header=0)

# creating a new column that will represent revenue in thousands of dollars
df['ResponsiveRevThous'] = df['ResponsiveRev']/1000

# making the year a categorical variable
df.Year.astype('category')

# setting the index to program and year. This makes python read the data as a panel
df = df.set_index(['Program','Year'])

# dropping old columns
var = df
var = var.drop(columns=['ResponsiveRev','srs','new_coach'])

# %%
# checking columns
var.columns
# Out:
# Index(['TwoStars', 'ThreeStars', 'FourStars', 'FiveStars', 'lagged_srs',
#        'stateunemp', 'stadium_cap', 'stadium_years_open',
#        'stadium_years_rennovation', 'num_homegames', 'coach_experience',
#        'conf_coy', 'nat_coy', 'coach_years_at_school', 'pop/d1prog',
#        'hs_grad_pct', 'pro_team_per_million', 'spring_practice', 'num_jcs',
#        'power', 'ResponsiveRevThous'],
#       dtype='object')

# %%
# making dataframes for Power 5 and Non Power 5
p5 = var[var['power'] == 1]
nonp5 =var[var['power'] == 0]

# %% [markdown]
# ### Summary Statistics

# %%
# printing a table with summary statistics for all teams
des = var.describe()
d = des.reset_index()

d.T
# Out:
#                                0            1            2        3  \
# index                      count         mean          std      min
# TwoStars                     378      33.3783      25.2668        0
# ThreeStars                   378      44.1376      17.6661        6
# FourStars                    378      14.1481      16.1375        0
# FiveStars                    378      1.25661      2.51895        0
# lagged_srs                   378        1.794      10.2467   -23.53
# stateunemp                   378      7.93989      1.92523     3.27
# stadium_cap                  378        56468      22394.3    20000
# stadium_years_open           378      61.1693      27.0236        0
# stadium_years_rennovation    378       7.0582      5.76432        0
# num_homegames                378      6.42063     0.728574        4
# coach_experience             378      6.54233      6.17727        0
# conf_coy                     378     0.531746     0.499653        0
# nat_coy                      378     0.177249     0.382385        0
# coach_years_at_school        378      3.76455      4.44598        0
# pop/d1prog                   378  2.37695e+06  1.46098e+06   564376
# hs_grad_pct                  378      88.3113      2.95003       82
# pro_team_per_million         378     0.294588     0.248038        0
# spring_practice              378      0.57672     0.494734        0
# num_jcs                      378      1.81217      3.37083        0
# power                        378     0.645503     0.478995        0
# ResponsiveRevThous           378      20868.1        21085  454.222
#
#                                      4            5            6            7
# index                              25%          50%          75%          max
# TwoStars                            12           25           58           96
# ThreeStars                          29           46           59           86
# FourStars                            1            9           21           62
# FiveStars                            0            0            1           16
# lagged_srs                      -5.345         2.17       8.7575        24.51
# stateunemp                        6.68         7.82         9.26         13.5
# stadium_cap                    36096.8        55000        72000       109901
# stadium_years_open                  43           64           86          101
# stadium_years_rennovation            3            6           10           27
# num_homegames                        6            6            7            8
# coach_experience                     2            5           10           28
# conf_coy                             0            1            1            1
# nat_coy                              0            0            0            1
# coach_years_at_school                1            2            5           27
# pop/d1prog                 1.44337e+06  1.97524e+06  2.84254e+06  8.94301e+06
# hs_grad_pct                    86.5925       88.215         90.9        94.86
# pro_team_per_million                 0     0.306768     0.457114      1.03661
# spring_practice                      0            1            1            1
# num_jcs                              0            0            1           14
# power                                0            1            1            1
# ResponsiveRevThous             3882.68      14827.9      30601.4       151380

# %%
# printing a table with summary statistics for Power 5 teams
desp5 = p5.describe()
dp5 = desp5.reset_index()

dp5.T
# Out:
#                                0            1           2        3  \
# index                      count         mean         std      min
# TwoStars                     244      17.4836     12.9133        0
# ThreeStars                   244      52.9508     12.8971       20
# FourStars                    244       21.373     15.9525        0
# FiveStars                    244      1.93443     2.92073        0
# lagged_srs                   244      6.19985     8.27634   -14.87
# stateunemp                   244      7.82201       1.937     3.27
# stadium_cap                  244      68544.7     17710.1    32740
# stadium_years_open           244      69.9959     26.0137        1
# stadium_years_rennovation    244      6.43852     4.97156        0
# num_homegames                244      6.70082    0.612489        5
# coach_experience             244      7.77869     6.33107        0
# conf_coy                     244     0.627049    0.484583        0
# nat_coy                      244     0.241803    0.429056        0
# coach_years_at_school        244      4.35246      4.9465        0
# pop/d1prog                   244  2.68956e+06  1.6112e+06   742609
# hs_grad_pct                  244      88.6663     2.88388       82
# pro_team_per_million         244     0.316663    0.253638        0
# spring_practice              244     0.590164    0.492814        0
# num_jcs                      244      1.97541     3.51941        0
# power                        244            1           0        1
# ResponsiveRevThous           244      30226.5     20838.3  4445.43
#
#                                      4            5            6            7
# index                              25%          50%          75%          max
# TwoStars                             8           15           23           68
# ThreeStars                          44           54        61.25           86
# FourStars                            9           16           33           62
# FiveStars                            0            1            3           16
# lagged_srs                       0.635        6.055        12.27        24.51
# stateunemp                      6.4575         7.76       9.2825        12.58
# stadium_cap                      55000      64150.5        82112       109901
# stadium_years_open                  53           83           89          101
# stadium_years_rennovation            2            6           10           25
# num_homegames                        6            7            7            8
# coach_experience                     3            6           11           28
# conf_coy                             0            1            1            1
# nat_coy                              0            0            0            1
# coach_years_at_school                1            3            6           27
# pop/d1prog                 1.54494e+06  2.20238e+06  3.37069e+06  8.94301e+06
# hs_grad_pct                    86.8675       88.905        90.96        94.04
# pro_team_per_million                 0     0.306013     0.454119      1.03661
# spring_practice                      0            1            1            1
# num_jcs                              0            0            1           14
# power                                1            1            1            1
# ResponsiveRevThous             15162.1      24237.8      40881.6       151380

# %%
# printing a table with summary statistics for Non Power 5 teams
desnonp5 = nonp5.describe()
dnonp5 = desnonp5.reset_index()

dnonp5.T
# Out:
#                                0            1         2        3            4  \
# index                      count         mean       std      min          25%
# TwoStars                     134      62.3209   14.0534       17           54
# ThreeStars                   134      28.0896   13.3706        6           19
# FourStars                    134     0.992537   1.75789        0            0
# FiveStars                    134    0.0223881  0.148497        0            0
# lagged_srs                   134     -6.22858   8.48596   -23.53     -11.7175
# stateunemp                   134      8.15455   1.89193     4.13        6.805
# stadium_cap                  134      34477.7   9681.36    20000        30000
# stadium_years_open           134       45.097   20.7469        0           39
# stadium_years_rennovation    134      8.18657   6.85858        0            3
# num_homegames                134      5.91045   0.64263        4            6
# coach_experience             134      4.29104   5.19807        0            1
# conf_coy                     134     0.358209  0.481273        0            0
# nat_coy                      134    0.0597015  0.237822        0            0
# coach_years_at_school        134      2.69403   3.08825        0            0
# pop/d1prog                   134  1.80773e+06    895300   564376  1.08103e+06
# hs_grad_pct                  134      87.6649      2.97       82      85.2125
# pro_team_per_million         134     0.254391   0.23309        0            0
# spring_practice              134     0.552239   0.49913        0            0
# num_jcs                      134      1.51493    3.0724        0            0
# power                        134            0         0        0            0
# ResponsiveRevThous           134      3827.41   3684.98  454.222      1417.56
#
#                                      5            6            7
# index                              50%          75%          max
# TwoStars                            66           71           96
# ThreeStars                          25           35           69
# FourStars                            0            1            9
# FiveStars                            0            0            1
# lagged_srs                      -6.155      -0.3025        18.69
# stateunemp                        7.83       9.0975         13.5
# stadium_cap                      30850        38019        65857
# stadium_years_open                  45         59.5           82
# stadium_years_rennovation            6           12           27
# num_homegames                        6            6            8
# coach_experience                     2            6           23
# conf_coy                             0            1            1
# nat_coy                              0            0            1
# coach_years_at_school                2            4           14
# pop/d1prog                 1.59907e+06  2.32937e+06  4.83766e+06
# hs_grad_pct                       87.5        90.69        94.86
# pro_team_per_million          0.307147     0.457114     0.792388
# spring_practice                      1            1            1
# num_jcs                              0            1           14
# power                                0            0            0
# ResponsiveRevThous              2640.9      4538.56      23819.1

# %% [markdown]
# ### Box Cox test to check for power tranformation

# %%
# importing stats library
from scipy import stats

# making a dataframe with only the dependent variable
transform = var['ResponsiveRevThous']

# running a Box Cox test on the dependent variable
x = stats.boxcox(transform)

# printing the Box Cox lambda
x[1]
# Out:
# 0.2143413854988545

# %% [markdown]
# Because the Box Cox lambda is close to 0, I will natural log my dependent variable.

# %%
# making an array with my dependent variable natural logged
# lmbda = 0 sets the transformation to natural log
xx = stats.boxcox(transform, lmbda = 0)

# %% [markdown]
# ### Shapiro-Wilk test for normality

# %%
# running a Shapiro-Wilk test
shapiro = stats.shapiro(xx)

# printing the p value
shapiro[1]
# Out:
# 1.1499772245571194e-09

# %% [markdown]
# I must reject the null hypothesis that my dependent variable is normally distributed.

# %%
# creating column with logged dependent variable
var['lnResponsiveRevThous'] = xx

# %% [markdown]
# ### Two Stage Least Squares

# %%
# defining dependent variable, exogenous variables, endogenous variables, and instruments
dependent = var.lnResponsiveRevThous
exog = var[['lagged_srs','stateunemp','num_homegames','stadium_cap','stadium_years_open','stadium_years_rennovation','coach_years_at_school','coach_experience','conf_coy','nat_coy']]
endog = var[['ThreeStars','FourStars','FiveStars']]
instruments = var[['pop/d1prog','num_jcs','spring_practice','hs_grad_pct','pro_team_per_million']]

# building model, running regression, returning results
mod = IV2SLS(dependent, exog, endog, instruments)
res = mod.fit()
res
# Out:
#                            IV-2SLS Estimation Summary
# ================================================================================
# Dep. Variable:     lnResponsiveRevThous   R-squared:                      0.9255
# Estimator:                      IV-2SLS   Adj. R-squared:                 0.9228
# No. Observations:                   378   F-statistic:                    8019.1
# Date:                  Fri, Oct 05 2018   P-value (F-stat)                0.0000
# Time:                          12:25:54   Distribution:                 chi2(13)
# Cov. Estimator:                  robust
#
#                                      Parameter Estimates
# =============================================================================================
#                            Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------
# lagged_srs                    0.0500     0.0315     1.5895     0.1119     -0.0117      0.1118
# stateunemp                    0.1991     0.0870     2.2886     0.0221      0.0286      0.3696
# num_homegames                 0.0051     0.2994     0.0169     0.9865     -0.5817      0.5918
# stadium_cap                   0.0002  2.854e-05     5.5077     0.0000      0.0001      0.0002
# stadium_years_open            0.0088     0.0047     1.8475     0.0647     -0.0005      0.0180
# stadium_years_rennovation    -0.0681     0.0238    -2.8648     0.0042     -0.1147     -0.0215
# coach_years_at_school         0.0641     0.0502     1.2748     0.2024     -0.0344      0.1625
# coach_experience             -0.0281     0.0413    -0.6800     0.4965     -0.1089      0.0528
# conf_coy                      0.0148     0.3027     0.0489     0.9610     -0.5784      0.6080
# nat_coy                       0.9352     0.5403     1.7309     0.0835     -0.1238      1.9943
# ThreeStars                    0.0547     0.0312     1.7533     0.0795     -0.0064      0.1158
# FourStars                    -0.4223     0.0940    -4.4922     0.0000     -0.6066     -0.2381
# FiveStars                     1.5727     0.5351     2.9393     0.0033      0.5240      2.6215
# =============================================================================================
#
# Endogenous: ThreeStars, FourStars, FiveStars
# Instruments: pop/d1prog, num_jcs, spring_practice, hs_grad_pct, pro_team_per_million
# Robust Covariance (Heteroskedastic)
# Debiased: False
# IVResults, id: 0x117020b38

# %% [markdown]
# ### Fixed Effects Model

# %%
panelx = var[['lagged_srs','stateunemp','num_homegames','stadium_cap','stadium_years_open','stadium_years_rennovation','coach_years_at_school','coach_experience','conf_coy','nat_coy','ThreeStars','FourStars','FiveStars']]
panelx = sm.add_constant(panelx)
panely = var['lnResponsiveRevThous']

mod = PanelOLS(panely, panelx, entity_effects=True)
fixed_effects = mod.fit()
print(fixed_effects)
# Out:
#                            PanelOLS Estimation Summary
# ==================================================================================
# Dep. Variable:     lnResponsiveRevThous   R-squared:                        0.4350
# Estimator:                     PanelOLS   R-squared (Between):             -0.5065
# No. Observations:                   378   R-squared (Within):               0.4350
# Date:                  Fri, Oct 05 2018   R-squared (Overall):             -0.4337
# Time:                          12:29:05   Log-likelihood                   -49.385
# Cov. Estimator:              Unadjusted
#                                           F-statistic:                      17.054
# Entities:                            77   P-value                           0.0000
# Avg Obs:                         4.9091   Distribution:                  F(13,288)
# Min Obs:                         1.0000
# Max Obs:                         5.0000   F-statistic (robust):             17.054
#                                           P-value                           0.0000
# Time periods:                         5   Distribution:                  F(13,288)
# Avg Obs:                         75.600
# Min Obs:                         74.000
# Max Obs:                         76.000
#
#                                      Parameter Estimates
# =============================================================================================
#                            Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ---------------------------------------------------------------------------------------------
# const                         12.373     0.5558     22.260     0.0000      11.279      13.467
# lagged_srs                    0.0082     0.0032     2.5370     0.0117      0.0018      0.0145
# stateunemp                   -0.1849     0.0138    -13.406     0.0000     -0.2121     -0.1578
# num_homegames                -0.0530     0.0342    -1.5521     0.1217     -0.1202      0.0142
# stadium_cap               -3.847e-06  6.747e-06    -0.5702     0.5690  -1.713e-05   9.432e-06
# stadium_years_open           -0.0117     0.0035    -3.3130     0.0010     -0.0187     -0.0048
# stadium_years_rennovation     0.0002     0.0067     0.0301     0.9760     -0.0130      0.0134
# coach_years_at_school        -0.0038     0.0100    -0.3855     0.7001     -0.0234      0.0158
# coach_experience              0.0140     0.0067     2.0986     0.0367      0.0009      0.0271
# conf_coy                     -0.0983     0.0682    -1.4412     0.1506     -0.2326      0.0360
# nat_coy                      -0.1517     0.0932    -1.6272     0.1048     -0.3351      0.0318
# ThreeStars                   -0.0079     0.0033    -2.4177     0.0162     -0.0144     -0.0015
# FourStars                    -0.0029     0.0068    -0.4356     0.6635     -0.0162      0.0104
# FiveStars                     0.0403     0.0238     1.6981     0.0906     -0.0064      0.0871
# =============================================================================================
#
# F-test for Poolability: 10.079
# P-value: 0.0000
# Distribution: F(76,288)
#
# Included effects: Entity
